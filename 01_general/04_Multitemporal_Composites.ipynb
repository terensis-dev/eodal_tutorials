# %% [markdown]
# # Landsat Multi-Temporal Composites
#
# In remote sensing, we usually work on single images ("scenes") acquired on a given date over a given area. While this sufficient or even necessary for many applications such as the studying of vegetation dynamics, some applications actually require information combined from many scenes, i.e., multiple "snapshots" of an area over time.
#
# Single scenes tend to be noisy mostly because of atmospheric disturbances and instrumentation errors. Thus single scenes might contain significant parts of no-data or poor-quality pixels due to instrument failures, clouds (in the case of optical imagery) or shadows. Taking multiple scenes acquired at different points in time and aggregating them over time by a statistical measure such as the mean or median is therefore in some cases the preferred choice.
#
# Multi-temporal composites are used for many different applications, including
#
# * inputs for classification tasks such as land-use/ land-cover mapping
# * generation of equidistant time series
# * generation of basemaps
#
# to name a few.
#
# In this notebook, you will learn how to generate a multi-temporal mosaic of Landsat8-9 scenes acquired in Spring 2022. Our example covers a full month (May 2022). The steps are:
#
# 1. We fetch the Landsat scenes overlapping our study region
# 2. We aggregate the Landsat scenes into a single multi-temporal composite using the median, i.e., our composite will contain the median reflectance obtained from all Landsat scenes fetched in May 2022

# %%
# we have to install the development version for the time being
# %pip uninstall eodal -y
# %pip install git+https://github.com/lukasValentin/eodal@landsat-dev
# Out:
# WARNING: Skipping eodal as it is not installed.
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/lukasValentin/eodal@landsat-dev
#   Cloning https://github.com/lukasValentin/eodal (to revision landsat-dev) to /tmp/pip-req-build-drbdpjtt
#   Running command git clone --filter=blob:none --quiet https://github.com/lukasValentin/eodal /tmp/pip-req-build-drbdpjtt
#   Running command git checkout -b landsat-dev --track origin/landsat-dev
#   Switched to a new branch 'landsat-dev'
#   branch 'landsat-dev' set up to track 'origin/landsat-dev'.
#   Resolved https://github.com/lukasValentin/eodal to commit 2e18f80fa8f3e9bd9cb5f3deb7dd836375d09e81
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pandas (from eodal==0.2.1)
#   Downloading pandas-2.0.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.2/12.2 MB 85.8 MB/s eta 0:00:0000:010:01
# Collecting geopandas (from eodal==0.2.1)
#   Using cached geopandas-0.13.2-py3-none-any.whl (1.1 MB)
# Collecting sqlalchemy (from eodal==0.2.1)
#   Downloading SQLAlchemy-2.0.18-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 91.7 MB/s eta 0:00:00
# Collecting geoalchemy2 (from eodal==0.2.1)
#   Downloading GeoAlchemy2-0.14.0-py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.0/54.0 kB 24.4 MB/s eta 0:00:00
# Collecting numpy (from eodal==0.2.1)
#   Downloading numpy-1.25.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.6/17.6 MB 82.2 MB/s eta 0:00:0000:0100:01
# Collecting pydantic-settings (from eodal==0.2.1)
#   Downloading pydantic_settings-2.0.2-py3-none-any.whl (11 kB)
# Collecting pyproj (from eodal==0.2.1)
#   Using cached pyproj-3.6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (8.0 MB)
# Collecting rasterio (from eodal==0.2.1)
#   Downloading rasterio-1.3.8-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 76.1 MB/s eta 0:00:0000:0100:01
# Collecting matplotlib (from eodal==0.2.1)
#   Downloading matplotlib-3.7.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 91.9 MB/s eta 0:00:0000:0100:01
# Collecting lxml (from eodal==0.2.1)
#   Downloading lxml-4.9.3-cp311-cp311-manylinux_2_28_x86_64.whl (7.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 98.7 MB/s eta 0:00:00:00:0100:01
# Collecting joblib (from eodal==0.2.1)
#   Downloading joblib-1.3.1-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 93.9 MB/s eta 0:00:00
# Collecting psycopg2-binary (from eodal==0.2.1)
#   Using cached psycopg2_binary-2.9.6-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
# Collecting opencv-python-headless (from eodal==0.2.1)
#   Downloading opencv_python_headless-4.8.0.74-cp37-abi3-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (49.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 57.7 MB/s eta 0:00:0000:0100:01
# Collecting requests (from eodal==0.2.1)
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting xarray (from eodal==0.2.1)
#   Using cached xarray-2023.6.0-py3-none-any.whl (999 kB)
# Collecting rtree (from eodal==0.2.1)
#   Using cached Rtree-1.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
# Collecting zarr (from eodal==0.2.1)
#   Using cached zarr-2.15.0-py3-none-any.whl (206 kB)
# Collecting numba (from eodal==0.2.1)
#   Using cached numba-0.57.1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (3.6 MB)
# Collecting pystac-client (from eodal==0.2.1)
#   Using cached pystac_client-0.7.2-py3-none-any.whl (33 kB)
# Collecting sentinelsat (from eodal==0.2.1)
#   Using cached sentinelsat-1.2.1-py3-none-any.whl (48 kB)
# Collecting pydantic[dotenv] (from eodal==0.2.1)
#   Downloading pydantic-2.0.3-py3-none-any.whl (364 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 364.0/364.0 kB 50.1 MB/s eta 0:00:00
# Collecting planetary-computer (from eodal==0.2.1)
#   Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Collecting alive-progress (from eodal==0.2.1)
#   Using cached alive_progress-3.1.4-py3-none-any.whl (75 kB)
# Collecting rasterstats (from eodal==0.2.1)
#   Using cached rasterstats-0.19.0-py3-none-any.whl (16 kB)
# Collecting pyyaml (from eodal==0.2.1)
#   Using cached PyYAML-6.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (757 kB)
# Collecting about-time==4.2.1 (from alive-progress->eodal==0.2.1)
#   Using cached about_time-4.2.1-py3-none-any.whl (13 kB)
# Collecting grapheme==0.6.0 (from alive-progress->eodal==0.2.1)
#   Using cached grapheme-0.6.0.tar.gz (207 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: packaging in /home/graflu/git/eodal_tutorials/.venv/lib64/python3.11/site-packages (from geoalchemy2->eodal==0.2.1) (23.1)
# Collecting typing-extensions>=4.2.0 (from sqlalchemy->eodal==0.2.1)
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy->eodal==0.2.1)
#   Using cached greenlet-2.0.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (618 kB)
# Collecting fiona>=1.8.19 (from geopandas->eodal==0.2.1)
#   Using cached Fiona-1.9.4.post1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (16.4 MB)
# Collecting shapely>=1.7.1 (from geopandas->eodal==0.2.1)
#   Using cached shapely-2.0.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.3 MB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/graflu/git/eodal_tutorials/.venv/lib64/python3.11/site-packages (from pandas->eodal==0.2.1) (2.8.2)
# Collecting pytz>=2020.1 (from pandas->eodal==0.2.1)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting tzdata>=2022.1 (from pandas->eodal==0.2.1)
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting certifi (from pyproj->eodal==0.2.1)
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting contourpy>=1.0.1 (from matplotlib->eodal==0.2.1)
#   Using cached contourpy-1.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (300 kB)
# Collecting cycler>=0.10 (from matplotlib->eodal==0.2.1)
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0 (from matplotlib->eodal==0.2.1)
#   Downloading fonttools-4.41.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 92.2 MB/s eta 0:00:00ta 0:00:01
# Collecting kiwisolver>=1.0.1 (from matplotlib->eodal==0.2.1)
#   Using cached kiwisolver-1.4.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
# Collecting pillow>=6.2.0 (from matplotlib->eodal==0.2.1)
#   Downloading Pillow-10.0.0-cp311-cp311-manylinux_2_28_x86_64.whl (3.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 93.4 MB/s eta 0:00:00:00:01
# Collecting pyparsing<3.1,>=2.3.1 (from matplotlib->eodal==0.2.1)
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Collecting llvmlite<0.41,>=0.40.0dev0 (from numba->eodal==0.2.1)
#   Using cached llvmlite-0.40.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.1 MB)
# Collecting numpy (from eodal==0.2.1)
#   Using cached numpy-1.24.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Collecting click>=7.1 (from planetary-computer->eodal==0.2.1)
#   Downloading click-8.1.5-py3-none-any.whl (98 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.1/98.1 kB 45.1 MB/s eta 0:00:00
# Collecting pystac>=1.0.0 (from planetary-computer->eodal==0.2.1)
#   Downloading pystac-1.8.2-py3-none-any.whl (175 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 70.3 MB/s eta 0:00:00
# Collecting python-dotenv (from planetary-computer->eodal==0.2.1)
#   Using cached python_dotenv-1.0.0-py3-none-any.whl (19 kB)
# Collecting charset-normalizer<4,>=2 (from requests->eodal==0.2.1)
#   Downloading charset_normalizer-3.2.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (199 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.6/199.6 kB 81.5 MB/s eta 0:00:00
# Collecting idna<4,>=2.5 (from requests->eodal==0.2.1)
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->eodal==0.2.1)
#   Using cached urllib3-2.0.3-py3-none-any.whl (123 kB)
# WARNING: pydantic 2.0.3 does not provide the extra 'dotenv'
# Collecting annotated-types>=0.4.0 (from pydantic[dotenv]->eodal==0.2.1)
#   Downloading annotated_types-0.5.0-py3-none-any.whl (11 kB)
# Collecting pydantic-core==2.3.0 (from pydantic[dotenv]->eodal==0.2.1)
#   Downloading pydantic_core-2.3.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 82.5 MB/s eta 0:00:00
# Collecting affine (from rasterio->eodal==0.2.1)
#   Using cached affine-2.4.0-py3-none-any.whl (15 kB)
# Collecting attrs (from rasterio->eodal==0.2.1)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting cligj>=0.5 (from rasterio->eodal==0.2.1)
#   Using cached cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Collecting snuggs>=1.4.1 (from rasterio->eodal==0.2.1)
#   Using cached snuggs-1.4.7-py3-none-any.whl (5.4 kB)
# Collecting click-plugins (from rasterio->eodal==0.2.1)
#   Using cached click_plugins-1.1.1-py2.py3-none-any.whl (7.5 kB)
# Requirement already satisfied: setuptools in /home/graflu/git/eodal_tutorials/.venv/lib64/python3.11/site-packages (from rasterio->eodal==0.2.1) (62.6.0)
# Collecting simplejson (from rasterstats->eodal==0.2.1)
#   Using cached simplejson-3.19.1-cp311-cp311-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (144 kB)
# Collecting html2text (from sentinelsat->eodal==0.2.1)
#   Using cached html2text-2020.1.16-py3-none-any.whl (32 kB)
# Collecting geojson>=2 (from sentinelsat->eodal==0.2.1)
#   Using cached geojson-3.0.1-py3-none-any.whl (15 kB)
# Collecting tqdm>=4.58 (from sentinelsat->eodal==0.2.1)
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting geomet (from sentinelsat->eodal==0.2.1)
#   Using cached geomet-1.0.0-py3-none-any.whl (28 kB)
# Collecting asciitree (from zarr->eodal==0.2.1)
#   Using cached asciitree-0.3.3.tar.gz (4.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting fasteners (from zarr->eodal==0.2.1)
#   Using cached fasteners-0.18-py3-none-any.whl (18 kB)
# Collecting numcodecs>=0.10.0 (from zarr->eodal==0.2.1)
#   Using cached numcodecs-0.11.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
# Requirement already satisfied: six in /home/graflu/git/eodal_tutorials/.venv/lib64/python3.11/site-packages (from fiona>=1.8.19->geopandas->eodal==0.2.1) (1.16.0)
# Collecting entrypoints (from numcodecs>=0.10.0->zarr->eodal==0.2.1)
#   Using cached entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Collecting jsonschema<4.18,>=4.0.1 (from pystac>=1.0.0->planetary-computer->eodal==0.2.1)
#   Using cached jsonschema-4.17.3-py3-none-any.whl (90 kB)
# Collecting pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 (from jsonschema<4.18,>=4.0.1->pystac>=1.0.0->planetary-computer->eodal==0.2.1)
#   Using cached pyrsistent-0.19.3-py3-none-any.whl (57 kB)
# Building wheels for collected packages: eodal, grapheme, asciitree
#   Building wheel for eodal (pyproject.toml) ... done
#   Created wheel for eodal: filename=eodal-0.2.1-py3-none-any.whl size=190337 sha256=5e08b9f6b361e2982619b0a5c8e13536d73aecae560cdb939ebe69dccce307a7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-u2eru5qw/wheels/2d/ef/47/5a8ebd8f2bc0aa9bc19e8e17cd1129e52d90ebeec080a79690
#   Building wheel for grapheme (pyproject.toml) ... done
#   Created wheel for grapheme: filename=grapheme-0.6.0-py3-none-any.whl size=210079 sha256=d5aa840044a7e97fef93badcfc8c77112e9f1af75dbcb6a51e591d3da087825f
#   Stored in directory: /home/graflu/.cache/pip/wheels/ee/3b/0b/1b865800e916d671a24028d884698674138632a83fdfad4926
#   Building wheel for asciitree (pyproject.toml) ... done
#   Created wheel for asciitree: filename=asciitree-0.3.3-py3-none-any.whl size=5034 sha256=4f713cf9088453dcfef7d88725f8e6ef0b357984c6d1aedb8053b02e83ad610a
#   Stored in directory: /home/graflu/.cache/pip/wheels/71/c1/da/23077eb3b87d24d6f3852ed1ed1a1ac2d3c885ad6ebd2b4a07
# Successfully built eodal grapheme asciitree
# Installing collected packages: pytz, grapheme, asciitree, urllib3, tzdata, typing-extensions, tqdm, simplejson, rtree, pyyaml, python-dotenv, pyrsistent, pyparsing, psycopg2-binary, pillow, numpy, lxml, llvmlite, kiwisolver, joblib, idna, html2text, greenlet, geojson, fonttools, fasteners, entrypoints, cycler, click, charset-normalizer, certifi, attrs, annotated-types, affine, about-time, sqlalchemy, snuggs, shapely, requests, pystac, pyproj, pydantic-core, pandas, opencv-python-headless, numcodecs, numba, jsonschema, geomet, contourpy, cligj, click-plugins, alive-progress, zarr, xarray, sentinelsat, rasterio, pydantic, matplotlib, geoalchemy2, fiona, rasterstats, pystac-client, pydantic-settings, geopandas, planetary-computer, eodal
# Successfully installed about-time-4.2.1 affine-2.4.0 alive-progress-3.1.4 annotated-types-0.5.0 asciitree-0.3.3 attrs-23.1.0 certifi-2023.5.7 charset-normalizer-3.2.0 click-8.1.5 click-plugins-1.1.1 cligj-0.7.2 contourpy-1.1.0 cycler-0.11.0 entrypoints-0.4 eodal-0.2.1 fasteners-0.18 fiona-1.9.4.post1 fonttools-4.41.0 geoalchemy2-0.14.0 geojson-3.0.1 geomet-1.0.0 geopandas-0.13.2 grapheme-0.6.0 greenlet-2.0.2 html2text-2020.1.16 idna-3.4 joblib-1.3.1 jsonschema-4.17.3 kiwisolver-1.4.4 llvmlite-0.40.1 lxml-4.9.3 matplotlib-3.7.2 numba-0.57.1 numcodecs-0.11.0 numpy-1.24.4 opencv-python-headless-4.8.0.74 pandas-2.0.3 pillow-10.0.0 planetary-computer-1.0.0 psycopg2-binary-2.9.6 pydantic-2.0.3 pydantic-core-2.3.0 pydantic-settings-2.0.2 pyparsing-3.0.9 pyproj-3.6.0 pyrsistent-0.19.3 pystac-1.8.2 pystac-client-0.7.2 python-dotenv-1.0.0 pytz-2023.3 pyyaml-6.0 rasterio-1.3.8 rasterstats-0.19.0 requests-2.31.0 rtree-1.0.1 sentinelsat-1.2.1 shapely-2.0.1 simplejson-3.19.1 snuggs-1.4.7 sqlalchemy-2.0.18 tqdm-4.65.0 typing-extensions-4.7.1 tzdata-2023.3 urllib3-2.0.3 xarray-2023.6.0 zarr-2.15.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Setting up the EOdal Mapper

# %%
from datetime import datetime
from pathlib import Path
from shapely.geometry import box

from eodal.config import get_settings
from eodal.core.sensors import Landsat
from eodal.mapper.feature import Feature
from eodal.mapper.filter import Filter
from eodal.mapper.mapper import Mapper, MapperConfigs

Settings = get_settings()
# we use STAC, i.e., Microsoft Planetary Computer
Settings.USE_STAC = True


# user-inputs
# -------------------------- Collection -------------------------------
collection = 'landsat-c2-l2'

# ---------------------- Spatial Feature  ------------------------------
bbox = box(*[7.0, 47.0, 8.0, 48.0])  # can be also shp, gpkg, etc.
feature = Feature(
    name='landsat-composite',
    geometry=bbox,
    epsg=4326,
    attributes={})

# ------------------------- Time Range ---------------------------------
time_start = datetime(2023, 6, 1)
time_end = datetime(2023, 6, 30)

# ------------------------- Metadata Filters ---------------------------
metadata_filters = [
    Filter('eo:cloud_cover', '<=', 70),
    Filter('instruments', '==', 'oli')
]

# set up the Mapper configuration
mapper_configs = MapperConfigs(
    metadata_filters=metadata_filters,
    collection=collection,
    feature=feature,
    time_start=time_start,
    time_end=time_end)
# get a new mapper instance
mapper = Mapper(mapper_configs)
mapper
# Out:
# EOdal Mapper
# ============
# EOdal MapperConfig
# ------------------
# Collection: landsat-c2-l2
# Time Range: 2023-06-01 00:00:00 - 2023-06-30 00:00:00
# Feature:
# Name		landsat-composite
# Geometry	POLYGON ((8 47, 8 48, 7 48, 7 47, 8 47))
# EPSG Code	4326
# Attributes	{}
# Metadata Filters: [eo:cloud_cover <= 70, instruments == oli]
# Data Source: STAC (https://planetarycomputer.microsoft.com/api/stac/v1)

# %%
# define a function to mask clouds and shadows
def prepocess_landsat_scene(
        ds: Landsat
) -> Landsat:
    """
    Mask clouds and cloud shadows in a Landsat scene based
    on the 'qa_pixel' band.

    NOTE:
        Depending on your needs, the pre-processing function can be
        fully customized using the full power of EOdal and its
        interfacing libraries!

    :param ds:
        Landsat scene before cloud mask applied.
    :return:
        Landsat scene with clouds and cloud shadows masked.
    """
    ds.mask_clouds_and_shadows(inplace=True)
    return ds

# %% [markdown]
# ## Query the data

# %%
# fetch the metadata
# query the scenes available (no I/O of scenes, this only fetches metadata)
mapper.query_scenes()

# the metadata is stored as a GeoDataFrame
mapper.metadata.head()
# Out:
#     gsd                      created           sci:doi   platform  proj:epsg  \
# 12   30  2023-06-09T09:15:04.895491Z  10.5066/P9OGBGM6  landsat-8      32632
# 11   30  2023-06-09T09:15:06.349166Z  10.5066/P9OGBGM6  landsat-8      32632
# 10   30  2023-06-16T09:15:02.049287Z  10.5066/P9OGBGM6  landsat-8      32632
# 9    30  2023-06-16T09:15:02.733546Z  10.5066/P9OGBGM6  landsat-8      32632
# 8    30  2023-06-14T09:15:09.252140Z  10.5066/P9OGBGM6  landsat-9      32632
#
#       proj:shape                   description  instruments  eo:cloud_cover  \
# 12  [8011, 7911]  Landsat Collection 2 Level-2  [oli, tirs]           16.97
# 11  [8031, 7921]  Landsat Collection 2 Level-2  [oli, tirs]           49.48
# 10  [8091, 8001]  Landsat Collection 2 Level-2  [oli, tirs]           18.07
# 9   [8101, 8001]  Landsat Collection 2 Level-2  [oli, tirs]           18.72
# 8   [8001, 7901]  Landsat Collection 2 Level-2  [oli, tirs]            7.33
#
#                                   proj:transform  ...  \
# 12  [30.0, 0.0, 304485.0, 0.0, -30.0, 5375115.0]  ...
# 11  [30.0, 0.0, 260685.0, 0.0, -30.0, 5218515.0]  ...
# 10  [30.0, 0.0, 232485.0, 0.0, -30.0, 5535315.0]  ...
# 9   [30.0, 0.0, 185985.0, 0.0, -30.0, 5379315.0]  ...
# 8   [30.0, 0.0, 297585.0, 0.0, -30.0, 5375115.0]  ...
#
#    landsat:collection_number landsat:collection_category  \
# 12                        02                          T1
# 11                        02                          T1
# 10                        02                          T1
# 9                         02                          T1
# 8                         02                          T1
#
#                                                assets  \
# 12  {'qa': {'href': 'https://landsateuwest.blob.co...
# 11  {'qa': {'href': 'https://landsateuwest.blob.co...
# 10  {'qa': {'href': 'https://landsateuwest.blob.co...
# 9   {'qa': {'href': 'https://landsateuwest.blob.co...
# 8   {'qa': {'href': 'https://landsateuwest.blob.co...
#
#                    sensing_time sensing_date  \
# 12  2023-06-01T10:15:48.860636Z   2023-06-01
# 11  2023-06-01T10:16:12.743204Z   2023-06-01
# 10  2023-06-08T10:21:41.609388Z   2023-06-08
# 9   2023-06-08T10:22:05.491956Z   2023-06-08
# 8   2023-06-09T10:15:55.009451Z   2023-06-09
#
#                                                  geom   epsg  \
# 12  POLYGON ((541815.000 5134785.000, 541815.000 5...  32632
# 11  POLYGON ((498315.000 4977585.000, 498315.000 5...  32632
# 10  POLYGON ((472515.000 5292585.000, 472515.000 5...  32632
# 9   POLYGON ((426015.000 5136285.000, 426015.000 5...  32632
# 8   POLYGON ((534615.000 5135085.000, 534615.000 5...  32632
#
#    sun_azimuth_angle sun_zenith_angle sensor_zenith_angle
# 12        144.923706        29.043510                   0
# 11        142.615312        28.076654                   0
# 10        146.000740        29.420568                   0
# 9         143.721034        28.439821                   0
# 8         143.415524        28.413947                   0
#
# [5 rows x 26 columns]

# %%
print(f'Number of Landsat scenes found: {mapper.metadata.shape[0]}')
# Out:
# Number of Landsat scenes found: 13

# %%
# we tell EOdal how to load the Landsat scenes using `Landsat.from_usgs`
# and pass on some kwargs, e.g., the selection of bands we want to read.
# in addition, we tell EOdal to mask out clouds and shadows and the fly
# while reading the data using the qa_pixel band (therefore, we set the
# `read_qa` flag to True.
scene_kwargs = {
    'scene_constructor': Landsat.from_usgs,
    'scene_constructor_kwargs': {
        'band_selection': ["blue", "green", "red", "nir08"],
        'read_qa': True},
    'scene_modifier': prepocess_landsat_scene,
    'scene_modifier_kwargs': {}}

# now we load the scenes
mapper.load_scenes(scene_kwargs=scene_kwargs)

# the scenes are loaded into a EOdal SceneCollection object
mapper.data
# Out:
# 2023-07-14 16:02:28,352 eodal        INFO     Starting extraction of landsat scenes
# 2023-07-14 16:05:28,568 eodal        INFO     Finished extraction of landsat scenes
# EOdal SceneCollection
# ----------------------
# # Scenes:    13
# Timestamps:    2023-06-01 10:15:48, 2023-06-01 10:16:12, 2023-06-08 10:21:41, 2023-06-08 10:22:05, 2023-06-09 10:15:55, 2023-06-16 10:21:36, 2023-06-16 10:22:00, 2023-06-17 10:15:58, 2023-06-17 10:16:22, 2023-06-24 10:21:47, 2023-06-24 10:22:11, 2023-06-25 10:15:49, 2023-06-25 10:16:13
# Scene Identifiers:    LC08_L2SP_195027_20230601_20230607_02_T1, LC08_L2SP_195028_20230601_20230607_02_T1, LC08_L2SP_196026_20230608_20230614_02_T1, LC08_L2SP_196027_20230608_20230614_02_T1, LC09_L2SP_195027_20230609_20230611_02_T1, LC09_L2SP_196026_20230616_20230618_02_T1, LC09_L2SP_196027_20230616_20230618_02_T1, LC08_L2SP_195027_20230617_20230623_02_T1, LC08_L2SP_195028_20230617_20230623_02_T1, LC08_L2SP_196026_20230624_20230630_02_T1, LC08_L2SP_196027_20230624_20230630_02_T1, LC09_L2SP_195027_20230625_20230627_02_T1, LC09_L2SP_195028_20230625_20230627_02_T1

# %%
# all scenes have the same shape, i.e., the same number of bands, rows and columns
shapes = [{timestamp: scene.get_values().shape} for timestamp, scene in mapper.data]
shapes
# Out:
# [{datetime.datetime(2023, 6, 1, 10, 15, 48): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 1, 10, 16, 12): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 8, 10, 21, 41): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 8, 10, 22, 5): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 9, 10, 15, 55): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 16, 10, 21, 36): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 16, 10, 22): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 17, 10, 15, 58): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 17, 10, 16, 22): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 24, 10, 21, 47): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 24, 10, 22, 11): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 25, 10, 15, 49): (8, 3754, 2583)},
#  {datetime.datetime(2023, 6, 25, 10, 16, 13): (8, 3754, 2583)}]

# %% [markdown]
# ## Display the single scenes
#
# The mapper returns the single scenes. As we told the EOdal to mask out clouds, a significant share if the pixels is masked out. We will aggregate them in the next step.

# %%
f = mapper.data.plot(band_selection=['nir08', 'red', 'green'], figsize=(10, 20), max_scenes_in_row=3)

# %% [markdown]
# ## Generating the composite
#
# We will now generate the composite. Here, we have to consider two things:
#
# 1. The data is stored as [numpy masked arrays](https://numpy.org/doc/stable/reference/maskedarray.generic.html) as we masked out clouds.
# 2. We therefore have to use masked arrays and the numpy ma functions that work on numpy masked arrays (i.e., the ignore masked values).
#
# First, we open masked arrays for storing the data:

# %%
import numpy as np

# open arrays for storing the data per band
shape = (len(mapper.data), list(shapes[0].values())[0][1], list(shapes[0].values())[0][2])
blue = np.ma.masked_array(data=np.ndarray(shape, dtype=float), mask=False)
red = np.zeros_like(blue)
green = np.zeros_like(blue)
nir08 = np.zeros_like(blue)

# %% [markdown]
# Next, we loop over the scenes.

# %%
# loop over scenes and store values
idx = 0
for _, scene in mapper.data:
    blue[idx, :, :] = scene['blue'].values
    red[idx, :, :] = scene['red'].values
    green[idx, :, :] = scene['green'].values
    nir08[idx, :, :] = scene['nir08'].values
    idx += 1

# %% [markdown]
# Finally, we aggregate the data using the median reflectance. Since we deal with masked arrays, we have to call [numpy.ma.median](https://numpy.org/doc/stable/reference/generated/numpy.ma.median.html) instead of the "normal" numpy.median function.

# %%
# calculate the median reflectance per spectral band
blue_median = np.ma.median(blue, axis=0)
green_median = np.ma.median(green, axis=0)
red_median = np.ma.median(red, axis=0)
nir08_median = np.ma.median(nir08, axis=0)

# %% [markdown]
# We store the results in a new RasterCollection.

# %%
# save the median reflectance to a new RasterCollection
from eodal.core.band import Band
from eodal.core.raster import RasterCollection

rc = RasterCollection()

bands = {'blue': blue_median, 'green': green_median, 'red': red_median, 'nir08': nir08_median}

for band_name, band_value in bands.items():
    rc.add_band(
        band_constructor=Band,
        values=band_value,
        band_name=f'{band_name}_median',
        geo_info=scene[band_name].geo_info)

rc
# Out:
# EOdal RasterCollection
# ----------------------
# # Bands:    4
# Band names:    blue_median, green_median, red_median, nir08_median
# Band aliases:

# %% [markdown]
# We plot the result and save it as GeoTiff (optional). As you can see, after the compositing there are still some no-data pixels left (white areas). This is because for some locations there were not enough cloud-free observations to compute the median - especially in the eastern part of the study area. This is most likely due to [Landsat orbit design and overpass frequency]().

# %%
f = rc.plot_multiple_bands(['nir08_median', 'red_median', 'green_median'], figsize=(10,10))

# %%
# save as GeoTiff
rc.to_rasterio('2306_landsat_median_composite.tif')
